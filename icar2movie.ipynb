# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import dask

import glob
import os
import sys

sys.path.append('/glade/u/home/currierw/src/icar/helpers')
import aggregate_parallel_files

# %matplotlib inline

# %%
icarOut='/glade/u/home/currierw/work/icar/crb/default_icar_test_run/output/'
aggregate_parallel_files.main(icarOut+'icar_out0000*.nc')
# Out:
# /glade/u/home/currierw/work/icar/crb/default_icar_test_run/output/icar_out000001_1990-09-30_12-00-00.nc
# /glade/u/home/currierw/work/icar/crb/default_icar_test_run/output/icar_out_1990-09-30_12-00-00.nc
# /glade/u/home/currierw/work/icar/crb/default_icar_test_run/output/icar_out000001_1990-10-01_12-00-00.nc
# /glade/u/home/currierw/work/icar/crb/default_icar_test_run/output/icar_out_1990-10-01_12-00-00.nc
# /glade/u/home/currierw/work/icar/crb/default_icar_test_run/output/icar_out000001_1990-10-02_12-00-00.nc
# /glade/u/home/currierw/work/icar/crb/default_icar_test_run/output/icar_out_1990-10-02_12-00-00.nc
# /glade/u/home/currierw/work/icar/crb/default_icar_test_run/output/icar_out000001_1990-10-03_12-00-00.nc
# /glade/u/home/currierw/work/icar/crb/default_icar_test_run/output/icar_out_1990-10-03_12-00-00.nc
# /glade/u/home/currierw/work/icar/crb/default_icar_test_run/output/icar_out000001_1990-10-04_12-00-00.nc
# ...

# %%
ds=xr.open_mfdataset('/glade/scratch/currierw/icar/crb/CCSM4/historical/icar_out_*.nc',combine='by_coords')
ds
# Out:
# <xarray.Dataset>
# Dimensions:                (lat_v: 420, lat_y: 419, level: 15, level_i: 15, lon_u: 293, lon_x: 292, time: 732)
# Coordinates:
#     v_lat                  (lat_v, lon_x) float64 dask.array<chunksize=(420, 292), meta=np.ndarray>
#     v_lon                  (lat_v, lon_x) float64 dask.array<chunksize=(420, 292), meta=np.ndarray>
#     lat                    (lat_y, lon_x) float64 dask.array<chunksize=(419, 292), meta=np.ndarray>
#     u_lon                  (lat_y, lon_u) float64 dask.array<chunksize=(419, 293), meta=np.ndarray>
#     lon                    (lat_y, lon_x) float64 dask.array<chunksize=(419, 292), meta=np.ndarray>
#     u_lat                  (lat_y, lon_u) float64 dask.array<chunksize=(419, 293), meta=np.ndarray>
#   * time                   (time) datetime64[ns] 1990-09-30T18:00:00 ... 1990-10-31T05:00:00.078427792
# Dimensions without coordinates: lat_v, lat_y, level, level_i, lon_u, lon_x
# Data variables:
# ...

# %%
ds['terrain'][0,:,:].plot(cmap='terrain',vmin=0,vmax=3500)

# %%
ds['ta2m'][0,:,:].plot()

# %%
states_url = 'http://eric.clst.org/assets/wiki/uploads/Stuff/gz_2010_us_040_00_5m.json'
states_gdf = gpd.read_file(states_url)
# ax.add_geometries(states_gdf.geometry, crs = ccrs.PlateCarree(),facecolor='none', edgecolor='black')

# %%
import holoviews as hv

import geoviews as gv
hv.extension('matplotlib')
# %opts QuadMesh Image [colorbar=True] Feature [apply_ranges=False]

gvds = gv.Dataset(ds['qv'][0:400,0,:,:])
images = gvds.to(gv.QuadMesh, ['lon','lat']).options(cmap='viridis',xlim=(-115, -99), ylim=(34, 44)) * gv.Polygons(states_gdf).opts(projection=ccrs.PlateCarree(), facecolor='None', edgecolor='black')
images = images.options(fig_size=300)
hv.save(images, 'hv_anim_qv.mp4', fps=8)
# images
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
# ...
